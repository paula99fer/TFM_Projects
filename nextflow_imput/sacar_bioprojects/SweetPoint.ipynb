# %%
import pandas as pd

# %%
SRA = pd.read_excel('C:/Users/paula/OneDrive/Documentos/0. Master Biologia Computacional UPM/TFM_CNB/Python scripts/FINALgoodclasf.xlsx')
SRAruns = SRA.loc[SRA['Jose_1'] == 'abiotic']['Run'].tolist()

ENA = pd.read_csv('C:/Users/paula/OneDrive/Documentos/0. Master Biologia Computacional UPM/TFM_CNB/SacarProjectsTXT/definitivo.txt', sep ='\t')
ENA = ENA[ENA["accession"].str.contains("accession") == False]

ENAabiotics = ENA[ENA['run_accession'].isin(SRAruns)]

groupbiop = ENAabiotics.groupby('study_accession')

bioprojects = {'Single':[],'Paired':[]}
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_7952\165889224.py:4: DtypeWarning: Columns (20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   ENA = pd.read_csv('C:/Users/paula/OneDrive/Documentos/0. Master Biologia Computacional UPM/TFM_CNB/SacarProjectsTXT/definitivo.txt', sep ='\t')

# %%
for name, group_df in groupbiop:
    counter = 0
    for library in group_df['library_layout']:
            if library == 'SINGLE':
                counter +=1
            elif library == 'PAIRED':
                counter+=2
    c = bpdic.get(counter, [])
    bpdic[counter] = c
    bpdic[counter].append(name)
print(bpdic)
# Out:
# {36: ['PRJDB4993', 'PRJNA267681', 'PRJNA279529', 'PRJNA303157', 'PRJNA305733', 'PRJNA338072', 'PRJNA411947', 'PRJNA445300', 'PRJNA448925', 'PRJNA490074', 'PRJNA497220', 'PRJNA526125', 'PRJNA526623', 'PRJNA556985', 'PRJNA593027'], 8: ['PRJDB6535', 'PRJNA233557', 'PRJNA261866', 'PRJNA287039', 'PRJNA288813', 'PRJNA289431', 'PRJNA313480', 'PRJNA317804', 'PRJNA329451', 'PRJNA360866', 'PRJNA401357', 'PRJNA407793', 'PRJNA408323', 'PRJNA415344', 'PRJNA427817', 'PRJNA432800', 'PRJNA448158', 'PRJNA478206', 'PRJNA480699', 'PRJNA485673'], 18: ['PRJDB7363', 'PRJEB15457', 'PRJEB28655', 'PRJNA259680', 'PRJNA397570', 'PRJNA485134'], 16: ['PRJDB8007', 'PRJEB20305', 'PRJEB21859', 'PRJNA218215', 'PRJNA229430', 'PRJNA336152', 'PRJNA344695', 'PRJNA354949', 'PRJNA362994', 'PRJNA377889', 'PRJNA395465', 'PRJNA395944', 'PRJNA448154', 'PRJNA472448', 'PRJNA485260', 'PRJNA490078'], 12: ['PRJDB8521', 'PRJEB31311', 'PRJEB6701', 'PRJNA218542', 'PRJNA240248', 'PRJNA295091', 'PRJNA309654', 'PRJNA321410', 'PRJNA32147
# ...

# %%
bpdic = {}
print('Bioproject - Runs cogidos - Runs del SRA')
for name, group_df in groupbiop:
    if len(group_df) != len(SRA.loc[SRA['BioProject'] == name]['Jose_1'].tolist()):
        print(name,len(group_df),len(SRA.loc[SRA['BioProject'] == name]['Jose_1'].tolist()))
# Out:
# Bioproject - Runs cogidos - Runs del SRA
# PRJNA229430 8 9
# PRJNA307616 17 18
# PRJNA317804 4 6
# PRJNA419930 1 4
# PRJNA486068 14 24
# PRJNA490074 18 22
# PRJNA494179 58 67

# %%
hola  = list(bpdic.keys())
hola.sort()
hola
# Out:
# [1,
#  2,
#  3,
#  4,
#  6,
#  8,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  16,
#  17,
#  18,
#  20,
#  21,
#  22,
#  23,
#  24,
#  26,
#  27,
#  28,
#  30,
#  32,
#  34,
#  35,
#  36,
#  40,
#  42,
#  44,
#  45,
#  48,
#  51,
#  52,
#  54,
#  56,
#  62,
#  64,
#  70,
#  72,
#  76,
#  78,
#  80,
#  82,
#  96,
#  112,
#  114,
#  132,
#  167,
#  192,
#  320,
#  456,
#  468,
#  1280]

# %%
sorted_dict = dict(sorted(bpdic.items()))
print(sorted_dict)
# Out:
# {1: ['PRJNA419930'], 2: ['PRJNA244597'], 3: ['PRJNA286795'], 4: ['PRJEB1937', 'PRJNA174789', 'PRJNA211822', 'PRJNA218632', 'PRJNA245347', 'PRJNA246543', 'PRJNA264526', 'PRJNA300877', 'PRJNA325672', 'PRJNA326982', 'PRJNA338114', 'PRJNA348100', 'PRJNA435910', 'PRJNA478205'], 6: ['PRJEB27682', 'PRJNA208614', 'PRJNA209324', 'PRJNA267682', 'PRJNA284487', 'PRJNA300876', 'PRJNA309655', 'PRJNA350795', 'PRJNA354802', 'PRJNA412712', 'PRJNA421490'], 8: ['PRJDB6535', 'PRJNA233557', 'PRJNA261866', 'PRJNA287039', 'PRJNA288813', 'PRJNA289431', 'PRJNA313480', 'PRJNA317804', 'PRJNA329451', 'PRJNA360866', 'PRJNA401357', 'PRJNA407793', 'PRJNA408323', 'PRJNA415344', 'PRJNA427817', 'PRJNA432800', 'PRJNA448158', 'PRJNA478206', 'PRJNA480699', 'PRJNA485673'], 10: ['PRJNA330623', 'PRJNA399864', 'PRJNA431488'], 11: ['PRJNA186735', 'PRJNA213635', 'PRJNA489081'], 12: ['PRJDB8521', 'PRJEB31311', 'PRJEB6701', 'PRJNA218542', 'PRJNA240248', 'PRJNA295091', 'PRJNA309654', 'PRJNA321410', 'PRJNA321477', 'PRJNA325245', 
# ...

# %%
bioprojectsJOAQUIN = sorted_dict[20]+sorted_dict[21]+sorted_dict[22]+sorted_dict[23]+sorted_dict[24]

# %%
dfbioprojectsJOAQUIN = ENA[ENA['study_accession'].isin(bioprojectsJOAQUIN)]

# %%
dfbioprojectsJOAQUIN
# Out:
#           accession run_accession experiment_accession sample_accession  \
# 48124  SAMEA3554078    ERR1025325           ERX1104197     SAMEA3554078
# 48125  SAMEA3554079    ERR1025326           ERX1104198     SAMEA3554079
# 48126  SAMEA3554080    ERR1025327           ERX1104199     SAMEA3554080
# 48127  SAMEA3554081    ERR1025328           ERX1104200     SAMEA3554081
# 48128  SAMEA3554082    ERR1025329           ERX1104201     SAMEA3554082
# ...             ...           ...                  ...              ...
# 66217  SAMN12371891    SRR9844298           SRX6598943     SAMN12371891
# 66218  SAMN12371890    SRR9844299           SRX6598944     SAMN12371890
# 66219  SAMN12371889    SRR9844300           SRX6598945     SAMN12371889
# 66220  SAMN12371887    SRR9844301           SRX6598946     SAMN12371887
# 66221  SAMN12371888    SRR9844302           SRX6598947     SAMN12371888
#
#       secondary_sample_accession study_accession secondary_study_accession  \
# ...

# %%
groupbiop = dfbioprojectsJOAQUIN.groupby('study_accession')

for name, group_df in groupbiop:
    group_df.to_csv(f"{name}.csv",sep='\t',index=False,header=False)

# %%
SRA.loc[SRA['BioProject'] == 'PRJNA229430']
# Out:
#           NameJose Experiment          SampleName_x  Tissue        Ecotype  \
# 14911  sample01662  SRX380951             No-0_00hr  leaves  Nossen (No-0)
# 14912  sample01663  SRX380952             No-0_06hr  leaves  Nossen (No-0)
# 14913  sample01664  SRX380953             No-0_09hr  leaves  Nossen (No-0)
# 14914  sample01665  SRX380954             No-0_24hr  leaves  Nossen (No-0)
# 14915  sample01666  SRX380955             slh1_00hr  leaves  Nossen (No-0)
# 14916  sample01667  SRX380956             slh1_06hr  leaves  Nossen (No-0)
# 14917  sample01668  SRX380957             slh1_09hr  leaves  Nossen (No-0)
# 14918  sample01669  SRX380958             slh1_24hr  leaves  Nossen (No-0)
# 38970  sample01670  SRX380959  Unassigned reads III  leaves  Nossen (No-0)
#
#                Genotype Treatment      Project  TotalReads  UniqueMappedRatio  \
# 14911         wild type      28°C  PRJNA229430      615654             0.0650
# ...

# %%
ENA.loc[ENA['study_accession'] == 'PRJNA229430']['study_title'].tolist()
# Out:
# ['EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
#  'EXPRSS: an Illumina based high-throughput expression-profiling method to reveal transcriptional dynamics - III',
# ...
